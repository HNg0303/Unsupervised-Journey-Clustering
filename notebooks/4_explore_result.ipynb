# %%
import pandas as pd

path = "../output/journey_runs/_prepared/data_raw_sample-0fc0a9ec_time-session-split_test0p2_gap90_max80_root6_auth1/canonical_events_android_semantics.csv"
canon_df = pd.read_csv(path)

# %%
canon_df.tail(50)

# %%
canon_df["famol"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 canon_df["famol"]
#
# NameError: name 'canon_df' is not defined

# %% [markdown]
# ## 2. Explore Journey

# %%
journey_path = "../output/journey_runs/EXACT_ch-c45i30o20_ng1-3_svd64_fdf3_mf20000_nw0p35_mcs100_ms5_sel-eom_gap90_jmin4_tdf3_ent0_chr1_boot0_test0p2/android_journeys.csv"
journey_df = pd.read_csv(journey_path)

# %%
journey_df[journey_df["cluster"] == -1].head(50)[["journey_id", "cluster", "sequence"]]
# Out:
#    journey_id  cluster                                           sequence
# 1     J000002       -1  action@<missing>#android/login_screen/click_lo...
# 2     J000003       -1  view@HOME -> view@android/Home -> action@andro...
# 3     J000004       -1  view@HOME -> view@android/Home -> action@andro...
# 4     J000005       -1  view@HOME -> view@android/Home -> view@android...
# 5     J000006       -1  view@MainAppActivity -> view@HOME -> view@andr...
# 6     J000007       -1  view@SplashActivity -> view@MainAppActivity ->...
# 7     J000008       -1  view@Splash -> view@SplashActivity -> view@Mai...
# 8     J000009       -1  view@HOME -> view@android/Home -> view@android...
# 9     J000010       -1  action@<missing>#internet_fprotect_screen/mana...
# 11    J000012       -1  view@MainAppActivity -> view@SplashActivity ->...
# 15    J000018       -1  view@MainAppActivity -> view@Splash -> view@HO...
# 16    J000019       -1  view@MainAppActivity -> view@Splash -> view@an...
# ...
