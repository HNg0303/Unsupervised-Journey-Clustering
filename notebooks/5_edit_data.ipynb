# %%
import pandas as pd

cluster_mapping_data = "../output/scores/july/ios/model_version=latest/ios_cluster_mapping.csv"
df = pd.read_csv(cluster_mapping_data)
df
# Out:
#      platform  cluster_id                                       cluster_name  \
# 0         ios          -1             Chưa phân loại | Journey hỗn hợp/nhiễu
# 1         ios           0  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 2         ios           1  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 3         ios           2  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 4         ios           3                     Home | Noti + search + Quét QR
# ...       ...         ...                                                ...
# 1435      ios        1434  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 1436      ios        1435  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 1437      ios        1436  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 1438      ios        1437  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
# 1439      ios        1438  Quản lý dịch vụ | Quản lý thiết bị | Xem thiết...
#
# ...

# %%
df["business_family"].unique()
# Out:
# <ArrowStringArray>
# [  'Chưa phân loại',  'Quản lý dịch vụ',             'Home',
#        'Thanh toán',        'Tài khoản', 'Trung tâm hỗ trợ',
#   'Đăng ký dịch vụ',          'Loyalty']
# Length: 8, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   platform                1440 non-null   str
#  1   cluster_id              1440 non-null   int64
#  2   cluster_name            1440 non-null   str
#  3   business_family         1440 non-null   str
#  4   business_submodule      1440 non-null   str
#  5   business_detail         599 non-null    str
#  6   naming_confidence       1440 non-null   str
#  7   naming_source           1440 non-null   str
#  8   needs_review            1440 non-null   bool
#  9   mass_coverage           1440 non-null   float64
#  10  family_score_share      1440 non-null   float64
#  11  submodule_score_share   1440 non-null   float64
#  12  medoid_agreement        1440 non-null   bool
#  13  reasoning               1440 non-null   str
#  14  supporting_evidence     1371 non-null   str
# ...

# %%
df[df["business_family"] != "Chưa phân loại"]["business_family"].value_counts()
# Out:
# business_family
# Quản lý dịch vụ     414
# Home                316
# Thanh toán          283
# Tài khoản           161
# Trung tâm hỗ trợ     99
# Loyalty              67
# Đăng ký dịch vụ      36
# Name: count, dtype: int64

# %%
df[df["business_family"] != "Chưa phân loại"][df["business_family"] == "Quản lý dịch vụ"]["business_submodule"].value_counts()
# Out:
# /var/folders/2d/72_xlwc5043_nzxm7c3x2t6r0000gp/T/ipykernel_26580/379409987.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["business_family"] != "Chưa phân loại"][df["business_family"] == "Quản lý dịch vụ"]["business_submodule"].value_counts()
# business_submodule
# Quản lý thiết bị               182
# Quản lý Wifi                   120
# Sức khoẻ mạng                   35
# Tổng quan dịch vụ               34
# Quản lý Modem                   16
# Khởi động Modem                 12
# Internet (Hợp đồng)              5
# Bảo vệ Internet                  4
# Mô hình mạng                     2
# Khôi phục dịch vụ                2
# Dịch vụ đi kèm (Ultra fast)      1
# FPT Play (Hợp đồng)              1
# Name: count, dtype: int64
